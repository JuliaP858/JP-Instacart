# %% [markdown]
# Merging and Exporting Data
#
# This script includes the following points:
#
# Step 3. Import the data.
#
# Step 4. Check the Output of Dataframes.
#
# Step 5. Merge df_prods with df_ords_combined.
#
# Step 6. Confirm the results of the merge using the merge flag.
#
# Step 7. Export the file.

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# string
path =r'/Users/juliapetke/Desktop/Career Foundry/Instacart Basket Analysis'

# %% [markdown]
# 3 Import Data

# %%
# import of orders_products_combined_pickle
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# import of Products data 
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'prods_new.csv'), index_col = False)

# %% [markdown]
# 4 Check Output of Dataframe

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     0.0         196                  1          0   both
# 1                     0.0       14084                  2          0   both
# 2                     0.0       12427                  3          0   both
# 3                     0.0       26088                  4          0   both
# 4                     0.0       26405                  5          0   both

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# 5 Determine a suitable way to combine the orders_products_combined dataframe with your products data set

# %%
# Merge the DataFrames with a different indicator column name
df_merged = df_prods.merge(df_orders_products_combined, on='product_id', indicator='merge_indicator')

# %%
df_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
# ...

# %% [markdown]
# 6 Confirm the results of the merge using the merge flag.

# %%
df_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32434207       49688      Fresh Foaming Cleanser        73             11
# 32434208       49688      Fresh Foaming Cleanser        73             11
# 32434209       49688      Fresh Foaming Cleanser        73             11
# 32434210       49688      Fresh Foaming Cleanser        73             11
# 32434211       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  orders_day_of_week  \
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# 7 Export the file.

# %%
#Export orders_products_merged file
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
